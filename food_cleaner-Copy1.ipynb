# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt; plt.rcdefaults()
data = pd.read_csv('food_coded.csv')
data.head(1)
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0  unknown       1          1               720           3.0           420.0
#
#    coffee                           comfort_food       comfort_food_reasons  \
# 0       2  Chips, chocolate, ,mozzarella sticks   Boredom, sadness, anxiety
#
#    comfort_food_reasons_coded   ...    soup  sports  thai_food  \
# 0                         2.0   ...     2.0     2.0          5
#
#   tortilla_calories  turkey_calories         type_sports veggies_day  \
# 0             940.0              690  None at the moment           5
#
#    vitamins  waffle_calories  weight
# 0         1             1315     230
#
# [1 rows x 61 columns]

# %%
comfort_reasons = data['comfort_food_reasons_coded'].value_counts()
print(comfort_reasons)
# Out:
# 2.0    49
# 1.0    22
# 3.0    18
# 9.0     5
# 5.0     4
# 7.0     3
# 4.0     3
# 8.0     1
# 6.0     1
# Name: comfort_food_reasons_coded, dtype: int64

# %%
import matplotlib 
matplotlib.rc('xtick', labelsize=8) 
matplotlib.rc('ytick', labelsize=8) 
objects = ('stress', 'boredom', 'depression','hunger', 'laziness', 'cold','happiness','tv','none')
y_pos = np.arange(len(objects))
performance = [22,49,18,3,4, 1, 3, 1, 5]
 
plt.bar(y_pos, performance, align='center', alpha=0.5, color='green')
plt.xticks(y_pos, objects)
plt.ylabel('Frequencies')
plt.title('Most common reason for eating')
 
plt.show()

# %%
eating_changes = data['eating_changes_coded'].value_counts()
print(eating_changes)
# Out:
# 1    75
# 2    36
# 3    11
# 4     3
# Name: eating_changes_coded, dtype: int64

# %%
matplotlib.rc('xtick', labelsize=12) 
matplotlib.rc('ytick', labelsize=12) 
objects = ('worse', 'better', 'the same', 'unclear')
y_pos = np.arange(len(objects))
performance = [75, 36, 11, 3]
 
plt.bar(y_pos, performance, align='center', alpha=0.5, color='crimson')
plt.xticks(y_pos, objects)
plt.ylabel('Frequencies')
plt.title('Eating changes since college')
 
plt.show()

# %%
data.shape
# Out:
# (125, 61)

# %%
# %pylab
# The usual preamble
import pandas as pd

# Make the graphs a bit prettier, and bigger
pd.set_option('display.mpl_style', 'default')
figsize = figsize(15, 5)

# Always display all the columns
pd.set_option('display.line_width', 5000) 
pd.set_option('display.max_columns', 60)
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib
# line_width has been deprecated, use display.width instead (currently both are
# identical)
# //anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2881: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#find messiness
data['GPA'].unique()
# Out:
# array(['unknown', 'personal', 'none', '3.79 bitch', '4', '3.92', '3.904',
#        '3.9', '3.89', '3.882', '3.87', '3.83', '3.8', '3.77', '3.75',
#        '3.73', '3.7', '3.68', '3.67', '3.654', '3.65', '3.63', '3.605',
#        '3.6', '3.5', '3.4', '3.35', '3.3', '3.292', '3.2', '3.1', '3',
#        '2.9', '2.8', '2.71', '2.6', '2.4', '2.25', '2.2'], dtype=object)

# %%
na_values = ['unknown', 'personal', 'none', '3.79 bitch']
df = pd.read_csv('food_coded.csv', na_values=na_values, dtype={'GPA': str})

# %%
df['GPA'].unique()
# Out:
# array([nan, '4', '3.92', '3.904', '3.9', '3.89', '3.882', '3.87', '3.83',
#        '3.8', '3.77', '3.75', '3.73', '3.7', '3.68', '3.67', '3.654',
#        '3.65', '3.63', '3.605', '3.6', '3.5', '3.4', '3.35', '3.3',
#        '3.292', '3.2', '3.1', '3', '2.9', '2.8', '2.71', '2.6', '2.4',
#        '2.25', '2.2'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array([1, 2])

# %%
# %matplotlib inline
df.boxplot(column=("GPA"), by="Gender")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-722ab31ba52e> in <module>()
#       1 get_ipython().magic(u'matplotlib inline')
# ----> 2 df.boxplot(column=("GPA"), by="Gender")
#
# //anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in boxplot(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    5579     ax = plots.boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    5580                        grid=grid, rot=rot, figsize=figsize, layout=layout,
# -> 5581                        return_type=return_type, **kwds)
#    5582     plt.draw_if_interactive()
#    5583     return ax
#
# //anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
# ...

# %%
data.boxplot(column=str("GPA"), by="grade_level")
